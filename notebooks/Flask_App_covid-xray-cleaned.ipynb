# %% [markdown]
# # Flask App Demo (cleaned)This notebook demonstrates how the simple Flask app (app.py) can be used to send requests to the model.

# %%
import requestsfrom PIL import Imageimport io# example client usagedef send_image(path):    url = 'http://127.0.0.1:5000/predict'    with open(path, 'rb') as f:        files = {'file': f}        r = requests.post(url, files=files)    return r.json()# send_image('path_to_sample.jpg')
